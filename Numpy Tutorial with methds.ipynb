# %% [markdown]
# # NUMPY
# - Numpy is a general purpose array-processing package. It provies a high-performance multidimentional array object, and tools for working with these arrays. It is the fundamental package for scientific computing with python

# %% [markdown]
# # What is an array
# - An array is a data structure that stires value of same data type. In python, this is the main difference between arrays and lists. While python lists can contain values corresponding to different data types, arrays in python can only contain values corresponding to same data type.

# %%
#Initially import numpy
import numpy as np

# %%
arr = np.array([1, 2, 3, 4])
print(arr)
# Out:
# [1 2 3 4]

# %%
my_lst = [1, 2, 3, 4, 5]
arr = np.array(my_lst)

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
print(arr)
# Out:
# [1 2 3 4 5]

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr.shape
# Out:
# (5,)

# %%
# Multinested array from lists
my_lst1 = [1, 2, 3, 4, 5]
my_lst2 = [2, 4, 6, 8, 10]
my_lst3 = [3, 6, 9, 12, 15]

arr = np.array([my_lst1, my_lst2, my_lst3])

# %%
arr
# Out:
# array([[ 1,  2,  3,  4,  5],
#        [ 2,  4,  6,  8, 10],
#        [ 3,  6,  9, 12, 15]])

# %%
arr.shape
# Out:
# (3, 5)

# %%
arr.reshape(5, 3)
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5,  2],
#        [ 4,  6,  8],
#        [10,  3,  6],
#        [ 9, 12, 15]])

# %%
# Check the shape of array
arr.shape
# Out:
# (3, 5)

# %%
print(arr.shape)
# Out:
# (3, 5)

# %%
arr.reshape(5, 4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 arr.reshape(5, 4)
#
# ValueError: cannot reshape array of size 15 into shape (5,4)

# %%
arr.reshape(1, 15)
# Out:
# array([[ 1,  2,  3,  4,  5,  2,  4,  6,  8, 10,  3,  6,  9, 12, 15]])

# %%
arr.shape
# Out:
# (3, 5)

# %% [markdown]
# ## Indexing in Arrays

# %%
# Accessing the array elements
arr
# Out:
# array([[ 1,  2,  3,  4,  5],
#        [ 2,  4,  6,  8, 10],
#        [ 3,  6,  9, 12, 15]])

# %%
arr1 = np.array([1, 2, 3, 4, 5])
print(arr1)
# Out:
# [1 2 3 4 5]

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr1[0]
# Out:
# np.int64(1)

# %%
print(arr1[0])
# Out:
# 1

# %%
# Indexing for multidimention
# arr[:,:] It give all rows and cols
# arr[0:2,0:2 It give two rows and two cols from the multidimentional array

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
# multidimentional array
my_lst4 = [1, 3, 5, 7, 9]
my_lst5 = [2, 4, 6, 8, 10]
my_lst6 = [1, 4, 7, 10, 13]

my_arr = np.array([my_lst4, my_lst5, my_lst6])
my_arr
# Out:
# array([[ 1,  3,  5,  7,  9],
#        [ 2,  4,  6,  8, 10],
#        [ 1,  4,  7, 10, 13]])

# %%
type(my_arr)
# Out:
# numpy.ndarray

# %%
my_arr[:,:]
# Out:
# array([[ 1,  3,  5,  7,  9],
#        [ 2,  4,  6,  8, 10],
#        [ 1,  4,  7, 10, 13]])

# %%
my_arr[0:2,0:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 my_arr[0:2,0:2]
#
# NameError: name 'my_arr' is not defined

# %%
my_arr[1:3,3:5]
# Out:
# array([[ 8, 10],
#        [10, 13]])
