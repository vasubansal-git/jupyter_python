# %%
1 + 1
# Out:
# 2

# %%
'''
hello my name is vasu bansal.
'''
# Out:
# '\nhello my name is vasu bansal.\n'

# %% [markdown]
# # python Tutorial
# ## Welcome to python tutorial
#
# - Datatype

# %%
1 + 1
# Out:
# 2

# %%
4 * 5
# Out:
# 20

# %%
2 * 10
# Out:
# 20

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
10 ** 2
# Out:
# 100

# %%
10 * 'vasu'
# Out:
# 'vasuvasuvasuvasuvasuvasuvasuvasuvasuvasu'

# %% [markdown]
# - Check the data type

# %%
type(1)
# Out:
# int

# %%
type("Hello")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# - Strings

# %%
"Hello"
# Out:
# 'Hello'

# %%
"Vasu bansal"
# Out:
# 'Vasu bansal'

# %%
type("Vasu bansal")
# Out:
# str

# %% [markdown]
# ## Variable Assignment

# %%
# syntax
# var_name = value

a = 10

# %%
type(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 type(a)
#
# NameError: name 'a' is not defined

# %%
a = 10
type(a)
# Out:
# int

# %%
# Mathematical operations with variable assignment

a = 10
b = 20

# %%
type(a)
type(b)
# Out:
# int

# %%
a * b
# Out:
# 200

# %%
print(a * b)
# Out:
# 200

# %%
print(a + b)
print(a / b)
print(a % b)
print((a * b) + (a / b))
# Out:
# 30
# 0.5
# 10
# 200.5

# %%
# Various ways of printing

print("Hello")
# Out:
# Hello

# %%
first_name = "Vasu"
last_name = "Bansal"

# %%
print("My fist name is {} and my last name is {}".format(first_name, last_name))
# Out:
# My fist name is Vasu and my last name is Bansal

# %%
print("My first name is {first} and my last name is {last}".format(first = first_name, last = last_name))
# Out:
# My first name is Vasu and my last name is Bansal

# %%
len("Vasu") #give the length of chars
# Out:
# 4

# %%
type(1.0)
# Out:
# float

# %%
type([1, 2, 3, 4, 5, 6])
# Out:
# list

# %%
type((1, 2, 3, 4, 5, 6))
# Out:
# tuple
