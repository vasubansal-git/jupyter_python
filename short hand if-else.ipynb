# %%
a = 90
b = 100

print("A is greater") if a > b else print("=") if a == b else print("B is greater")

c = 9 if a > b else 0
print(c)
# Out:
# B is greater
# 0

# %%
age = int(input("Enter your age: "))

canVote = print("Can Vote") if age >= 18 else print("Cannot Vote")
# Out:
# Enter your age:  20
# Can Vote

# %%
num = int(input("Enter your number: "))

result = "Positive" if num > 0 else "Zero" if num == 0 else "Negative"
print(result)
# Out:
# Enter your number:  -1
# Negative

# %%
num = int(input("Enter your number: "))

evenOdd = "Even" if num % 2 == 0 else "Odd"
print(evenOdd)
# Out:
# Enter your number:  4
# Even
