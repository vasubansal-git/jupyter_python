# %% [markdown]
# # PANDAS
# ## Pandas ia an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the python programming language.

# %% [markdown]
# ## Agenda
# - What is Data Frames?
# - What is Data Series?
# - Different operation in Pandas

# %%
# First step is to import pandas

import pandas as pd
import numpy as np

# %%
# Playing with dataframe

df = pd.DataFrame(np.arange(0, 20).reshape(5,4),index=['Row1', 'Row2', 'Row3', 'Row4', 'Row5'], columns=['Column1', 'Column2', 'Column3', 'Column4'])

# %%
df['Column3']
# Out:
# Row1     2
# Row2     6
# Row3    10
# Row4    14
# Row5    18
# Name: Column3, dtype: int64

# %%
type(df['Column3'])
# Out:
# pandas.core.series.Series

# %%
df[['Column1', 'Column4']] # For getting multiple columns we need to create a list
# Out:
#       Column1  Column4
# Row1        0        3
# Row2        4        7
# Row3        8       11
# Row4       12       15
# Row5       16       19

# %%
df.head()
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
df.to_csv('Test1.csv')

# %%
# Accessing the elements
# 1. .loc   2.  .iloc

df.loc['Row1']
# Out:
# Column1    0
# Column2    1
# Column3    2
# Column4    3
# Name: Row1, dtype: int64

# %%
type(df.loc['Row1'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[:,:]
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
df.iloc[0:2,0:4]
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7

# %%
# Check type
type(df.iloc[0:2,0:4])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[0:2,0]
# Out:
# Row1    0
# Row2    4
# Name: Column1, dtype: int64

# %%
type(df.iloc[0:2,0])
# Out:
# pandas.core.series.Series

# %%
# Take the elements from the column2

df.iloc[:,1:]
# Out:
#       Column2  Column3  Column4
# Row1        1        2        3
# Row2        5        6        7
# Row3        9       10       11
# Row4       13       14       15
# Row5       17       18       19

# %%
# Convert DataFrames into array
df.iloc[:,1:].values
# Out:
# array([[ 1,  2,  3],
#        [ 5,  6,  7],
#        [ 9, 10, 11],
#        [13, 14, 15],
#        [17, 18, 19]])

# %%
df.isnull().sum()
# Out:
# Column1    0
# Column2    0
# Column3    0
# Column4    0
# dtype: int64

# %%
df
# Out:
#       Column1  Column2  Column3  Column4
# Row1        0        1        2        3
# Row2        4        5        6        7
# Row3        8        9       10       11
# Row4       12       13       14       15
# Row5       16       17       18       19

# %%
df['Column1'].value_counts()
# Out:
# Column1
# 0     1
# 4     1
# 8     1
# 12    1
# 16    1
# Name: count, dtype: int64

# %%
df['Column1'].unique()
# Out:
# array([ 0,  4,  8, 12, 16])
